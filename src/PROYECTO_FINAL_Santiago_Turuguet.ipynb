# %% [markdown]
# <a href="https://colab.research.google.com/github/gastonviveros2411/labo2025v/blob/main/Problema_16_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 04:49:38 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660358 35.3 1454502    77.7 1454502  77.7
# Vcells 1226536  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %%
# Ejecuta un pequeño script JavaScript desde R para mantener activa la sesión
IRdisplay::display_javascript("
function clickConnect() {
  console.log('Manteniendo sesión activa desde R...');
  const btn = document.querySelector('#top-toolbar > colab-connect-button');
  if (btn && btn.shadowRoot) {
    const connect = btn.shadowRoot.querySelector('#connect');
    if (connect) connect.click();
  }
}
setInterval(clickConnect, 60000);
")

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 100043

PARAM$experimento <- 6300
PARAM$dataset <- "gerencial_competencia_2025.csv"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := as.integer(foto_mes) %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %% [markdown]
# ## Configuración de Experimentos - TS Training Strategy #16
#
# ### Objetivo
# Evaluar el impacto de las variables clave `numero_de_cliente` y `foto_mes` en el modelo de predicción de churn.
#
# ### Experimentos disponibles:
#
# 1. **Modelo Base**: Incluye todas las variables (referencia)
# 2. **Exclusión de numero_de_cliente**: Elimina el identificador del cliente
# 3. **Exclusión de foto_mes**: Elimina la variable temporal
# 4. **Exclusión de ambas**: Elimina tanto numero_de_cliente como foto_mes
#
# ### Instrucciones:
# 1. Modifique la celda de configuración anterior para seleccionar el experimento deseado
# 2. Ejecute todo el notebook
# 3. Registre los resultados (ganancia promedio) para cada configuración
# 4. Compare los resultados para determinar la estrategia óptima

# %%
# Seleccione UNO de los siguientes experimentos descomentando la línea correspondiente:
# (Asegúrese de que solo UNA línea esté descomentada)

# Experimento 1: Modelo Base - Incluye todas las variables
#  PARAM$excluir_campos <- c()  # <- ACTIVO POR DEFECTO

# Experimento 2: Exclusión de numero_de_cliente
# PARAM$excluir_campos <- c("numero_de_cliente")

# Experimento 3: Exclusión de foto_mes
# PARAM$excluir_campos <- c("foto_mes")

# Experimento 4: Exclusión de ambas variables
 PARAM$excluir_campos <- c("numero_de_cliente", "foto_mes")

# Imprimir configuración activa
cat("\n========== CONFIGURACIÓN ACTIVA ==========\n")
if (length(PARAM$excluir_campos) == 0) {
    cat("Experimento 1: Modelo Base (todas las variables incluidas)\n")
} else if (identical(PARAM$excluir_campos, c("numero_de_cliente"))) {
    cat("Experimento 2: Exclusión de numero_de_cliente\n")
} else if (identical(PARAM$excluir_campos, c("foto_mes"))) {
    cat("Experimento 3: Exclusión de foto_mes\n")
} else if (setequal(PARAM$excluir_campos, c("numero_de_cliente", "foto_mes"))) {
    cat("Experimento 4: Exclusión de numero_de_cliente y foto_mes\n")
}
cat("Campos a excluir:", ifelse(length(PARAM$excluir_campos) == 0, "Ninguno", paste(PARAM$excluir_campos, collapse=", ")), "\n")
cat("==========================================\n\n")
# Out:
# ========== CONFIGURACIÓN ACTIVA ==========
# Experimento 4: Exclusión de numero_de_cliente y foto_mes
# Campos a excluir: numero_de_cliente, foto_mes
# ==========================================

# %%
# los campos en los que se entrena
# Primero obtenemos todos los campos menos los que siempre se excluyen
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# Ahora excluimos los campos según el experimento configurado
if (exists("PARAM") && !is.null(PARAM$excluir_campos) && length(PARAM$excluir_campos) > 0) {
    cat("Excluyendo campos del entrenamiento:", paste(PARAM$excluir_campos, collapse=", "), "\n")
    campos_buenos <- setdiff(campos_buenos, PARAM$excluir_campos)
    cat("Total de campos después de exclusión:", length(campos_buenos), "\n\n")
} else {
    cat("No se excluyen campos adicionales del entrenamiento\n")
    cat("Total de campos:", length(campos_buenos), "\n\n")
}
# Out:
# Excluyendo campos del entrenamiento: numero_de_cliente, foto_mes
# Total de campos después de exclusión: 155

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16551

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# ============================================================
#    OPTIMIZACIÓN LIGHTGBM FULL POWER
# ============================================================

# Cantidad de iteraciones de Bayesian Optimization
PARAM$hipeparametertuning$num_interations <- 250

# ------------------------------------------------------------
#  PARÁMETROS FIJOS (NO SE OPTIMIZAN)
#  Basados en tus requerimientos y el paper
# ------------------------------------------------------------
PARAM$lgbm$param_fijos <- list(
  objective              = "binary",
  metric                 = "auc",
  first_metric_only      = TRUE,
  boost_from_average     = TRUE,
  feature_pre_filter     = FALSE,
  verbosity              = -100,
  force_row_wise         = TRUE,
  seed                   = PARAM$semilla_primigenia,

  # Tus parámetros neutrales
  max_bin                = 31,
  learning_rate          = 0.03,

  # Recomendados por el paper (robustez)
  feature_fraction       = 0.8,
  bagging_fraction       = 0.8,
  bagging_freq           = 1,

  # Mejor método para clases extremadamente raras
  sampling_method        = "goss",

  # Entrenamiento largo (lo corta el early stopping)
  num_iterations         = 15000,
  early_stopping_rounds  = 400
)

# ------------------------------------------------------------
#  HIPERPARÁMETROS A OPTIMIZAR (Basados 100% en el Paper)
# ------------------------------------------------------------
PARAM$hipeparametertuning$hs <- makeParamSet(

  # PARAMETRO Nº1 MÁS IMPORTANTE SEGÚN EL PAPER
  makeIntegerParam("num_leaves", lower = 64L, upper = 1024L),

  # PARAMETRO Nº2 (CONTROL DEL OVERFITTING)
  makeIntegerParam("min_data_in_leaf", lower = 200L, upper = 2000L),

  # PROFUNDIDAD (RECOMENDADO 8–16)
  makeIntegerParam("max_depth", lower = 6L, upper = 18L),

  # REGULARIZACIÓN (MUY IMPORTANTE PARA EXTREME IMBALANCE)
  makeNumericParam("lambda_l1", lower = 0.1, upper = 5),
  makeNumericParam("lambda_l2", lower = 0.1, upper = 5),

  # EVITA SPLITS INÚTILES (MEJORA AUC EN RUIDO)
  makeNumericParam("min_gain_to_split", lower = 0.01, upper = 0.2)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Sun Nov 30 05:03:05 PM 2025 AUC 0.930524191399489
#
# [mbo] 121: num_leaves=348; min_data_in_leaf=217; max_depth=8; lambda_l1=1.52; lambda_l2=0.266; min_gain_to_split=0.0542 : y = 0.931 : 115.5 secs : infill_ei
#
# Saved the current state after iteration 122 in the file HT.RDATA.
#
# Sun Nov 30 05:04:46 PM 2025 AUC 0.931824764411614
#
# [mbo] 122: num_leaves=474; min_data_in_leaf=330; max_depth=10; lambda_l1=0.536; lambda_l2=3.46; min_gain_to_split=0.071 : y = 0.932 : 99.9 secs : infill_ei
#
# Sun Nov 30 05:05:59 PM 2025 AUC 0.926330521179205
#
# [mbo] 123: num_leaves=193; min_data_in_leaf=1923; max_depth=6; lambda_l1=2.67; lambda_l2=4.2; min_gain_to_split=0.173 : y = 0.926 : 71.4 secs : infill_ei
#
# Sun Nov 30 05:07:16 PM 2025 AUC 0.92991526464448
#
# [mbo] 124: num_leaves=373; min_data_in_leaf=220; max_depth=9; lambda_l1=0.519; lambda_l2=3.03; min_gain_to_split=0.117 : y = 0.93 : 76.6 secs : infill_ei
#
# Sun Nov 30 05:08:39 PM 2025 AUC 0.927752045396092
#
# [mbo] 125: num_leaves=505; min_data_in_leaf=1491; max_depth=13; lambda_l1=0.203; lambda_l2=3.1; min_gain_to_split=0.0209 : y = 0.928 : 81.8 secs : infill_ei
#
# Sun Nov 30 05:10:33 PM 2025 AUC 0.92652724066741
#
# [mbo] 126: num_leaves=278; min_data_in_leaf=1417; max_depth=10; lambda_l1=0.91; lambda_l2=3.03; min_gain_to_split=0.0701 : y = 0.927 : 112.8 secs : infill_ei
#
# Sun Nov 30 05:12:32 PM 2025 AUC 0.929694447598238
#
# [mbo] 127: num_leaves=763; min_data_in_leaf=1109; max_depth=11; lambda_l1=4.55; lambda_l2=2.71; min_gain_to_split=0.111 : y = 0.93 : 117.8 secs : infill_ei
#
# Sun Nov 30 05:14:08 PM 2025 AUC 0.927330106423158
#
# [mbo] 128: num_leaves=965; min_data_in_leaf=1003; max_depth=14; lambda_l1=1.85; lambda_l2=3.81; min_gain_to_split=0.0977 : y = 0.927 : 95.4 secs : infill_ei
#
# Saved the current state after iteration 129 in the file HT.RDATA.
#
# Sun Nov 30 05:16:38 PM 2025 AUC 0.931070788893806
#
# [mbo] 129: num_leaves=374; min_data_in_leaf=1093; max_depth=10; lambda_l1=0.234; lambda_l2=3.96; min_gain_to_split=0.0869 : y = 0.931 : 149.6 secs : infill_ei
#
# Sun Nov 30 05:18:00 PM 2025 AUC 0.926023740728812
#
# [mbo] 130: num_leaves=396; min_data_in_leaf=1753; max_depth=14; lambda_l1=0.873; lambda_l2=4.22; min_gain_to_split=0.0573 : y = 0.926 : 81.4 secs : infill_ei
#
# Sun Nov 30 05:19:46 PM 2025 AUC 0.933157776444174
#
# [mbo] 131: num_leaves=525; min_data_in_leaf=289; max_depth=12; lambda_l1=0.352; lambda_l2=3.66; min_gain_to_split=0.15 : y = 0.933 : 104.3 secs : infill_ei
#
# Sun Nov 30 05:21:55 PM 2025 AUC 0.930478081649014
#
# [mbo] 132: num_leaves=503; min_data_in_leaf=329; max_depth=12; lambda_l1=0.527; lambda_l2=0.126; min_gain_to_split=0.0781 : y = 0.93 : 128.8 secs : infill_ei
#
# Sun Nov 30 05:23:16 PM 2025 AUC 0.926965399150561
#
# [mbo] 133: num_leaves=326; min_data_in_leaf=1820; max_depth=13; lambda_l1=0.489; lambda_l2=2.57; min_gain_to_split=0.179 : y = 0.927 : 80.4 secs : infill_ei
#
# Sun Nov 30 05:25:35 PM 2025 AUC 0.925754960273785
#
# [mbo] 134: num_leaves=809; min_data_in_leaf=1533; max_depth=18; lambda_l1=0.314; lambda_l2=3.09; min_gain_to_split=0.0743 : y = 0.926 : 137.5 secs : infill_ei
#
# Saved the current state after iteration 135 in the file HT.RDATA.
#
# Sun Nov 30 05:27:01 PM 2025 AUC 0.926602545536275
#
# [mbo] 135: num_leaves=728; min_data_in_leaf=1113; max_depth=11; lambda_l1=4.13; lambda_l2=2.59; min_gain_to_split=0.102 : y = 0.927 : 85.9 secs : infill_ei
#
# Sun Nov 30 05:28:17 PM 2025 AUC 0.926641240653507
#
# [mbo] 136: num_leaves=776; min_data_in_leaf=1952; max_depth=13; lambda_l1=1.66; lambda_l2=4.37; min_gain_to_split=0.11 : y = 0.927 : 75.0 secs : infill_ei
#
# Sun Nov 30 05:30:37 PM 2025 AUC 0.92958832565996
#
# [mbo] 137: num_leaves=297; min_data_in_leaf=785; max_depth=18; lambda_l1=0.94; lambda_l2=4.85; min_gain_to_split=0.0845 : y = 0.93 : 139.3 secs : infill_ei
#
# Sun Nov 30 05:32:15 PM 2025 AUC 0.926918362570931
#
# [mbo] 138: num_leaves=866; min_data_in_leaf=1937; max_depth=17; lambda_l1=4.09; lambda_l2=4.94; min_gain_to_split=0.199 : y = 0.927 : 97.0 secs : infill_ei
#
# Sun Nov 30 05:34:08 PM 2025 AUC 0.931525630301752
#
# [mbo] 139: num_leaves=142; min_data_in_leaf=284; max_depth=8; lambda_l1=0.975; lambda_l2=1.15; min_gain_to_split=0.0705 : y = 0.932 : 111.7 secs : infill_ei
#
# Sun Nov 30 05:36:04 PM 2025 AUC 0.926680862599895
#
# [mbo] 140: num_leaves=98; min_data_in_leaf=1752; max_depth=12; lambda_l1=4.55; lambda_l2=4.69; min_gain_to_split=0.167 : y = 0.927 : 114.8 secs : infill_ei
#
# Saved the current state after iteration 141 in the file HT.RDATA.
#
# Sun Nov 30 05:37:48 PM 2025 AUC 0.930691484062014
#
# [mbo] 141: num_leaves=387; min_data_in_leaf=403; max_depth=14; lambda_l1=1.9; lambda_l2=4.34; min_gain_to_split=0.198 : y = 0.931 : 103.1 secs : infill_ei
#
# Sun Nov 30 05:39:07 PM 2025 AUC 0.92679532600057
#
# [mbo] 142: num_leaves=389; min_data_in_leaf=1365; max_depth=12; lambda_l1=4.8; lambda_l2=4.99; min_gain_to_split=0.14 : y = 0.927 : 77.5 secs : infill_ei
#
# Sun Nov 30 05:41:42 PM 2025 AUC 0.933512056888774
#
# [mbo] 143: num_leaves=389; min_data_in_leaf=333; max_depth=12; lambda_l1=0.155; lambda_l2=0.802; min_gain_to_split=0.149 : y = 0.934 : 153.4 secs : infill_ei
#
# Sun Nov 30 05:43:09 PM 2025 AUC 0.928307679474673
#
# [mbo] 144: num_leaves=987; min_data_in_leaf=640; max_depth=13; lambda_l1=3.23; lambda_l2=4.87; min_gain_to_split=0.0808 : y = 0.928 : 86.2 secs : infill_ei
#
# Sun Nov 30 05:44:38 PM 2025 AUC 0.927969155125713
#
# [mbo] 145: num_leaves=369; min_data_in_leaf=1476; max_depth=16; lambda_l1=0.818; lambda_l2=1.04; min_gain_to_split=0.0367 : y = 0.928 : 88.2 secs : infill_ei
#
# Sun Nov 30 05:46:25 PM 2025 AUC 0.931178764490395
#
# [mbo] 146: num_leaves=339; min_data_in_leaf=202; max_depth=12; lambda_l1=0.936; lambda_l2=1.48; min_gain_to_split=0.15 : y = 0.931 : 105.2 secs : infill_ei
#
# Saved the current state after iteration 147 in the file HT.RDATA.
#
# Sun Nov 30 05:48:12 PM 2025 AUC 0.931397959585615
#
# [mbo] 147: num_leaves=281; min_data_in_leaf=203; max_depth=10; lambda_l1=0.579; lambda_l2=2.5; min_gain_to_split=0.0703 : y = 0.931 : 106.0 secs : infill_ei
#
# Sun Nov 30 05:49:58 PM 2025 AUC 0.929664093943403
#
# [mbo] 148: num_leaves=449; min_data_in_leaf=543; max_depth=10; lambda_l1=0.966; lambda_l2=2.34; min_gain_to_split=0.0663 : y = 0.93 : 104.7 secs : infill_ei
#
# Sun Nov 30 05:51:26 PM 2025 AUC 0.930127971935613
#
# [mbo] 149: num_leaves=417; min_data_in_leaf=232; max_depth=10; lambda_l1=1.59; lambda_l2=3.11; min_gain_to_split=0.154 : y = 0.93 : 86.8 secs : infill_ei
#
# Sun Nov 30 05:52:27 PM 2025 AUC 0.930094837793312
#
# [mbo] 150: num_leaves=785; min_data_in_leaf=348; max_depth=6; lambda_l1=0.346; lambda_l2=1.25; min_gain_to_split=0.104 : y = 0.93 : 60.2 secs : infill_ei
#
# Sun Nov 30 05:54:36 PM 2025 AUC 0.931429471776894
#
# [mbo] 151: num_leaves=240; min_data_in_leaf=458; max_depth=18; lambda_l1=0.798; lambda_l2=1.57; min_gain_to_split=0.158 : y = 0.931 : 128.1 secs : infill_ei
#
# Sun Nov 30 05:55:57 PM 2025 AUC 0.928839911117084
#
# [mbo] 152: num_leaves=296; min_data_in_leaf=739; max_depth=8; lambda_l1=3.83; lambda_l2=3.55; min_gain_to_split=0.0452 : y = 0.929 : 80.1 secs : infill_ei
#
# Sun Nov 30 05:57:13 PM 2025 AUC 0.926947094274745
#
# [mbo] 153: num_leaves=584; min_data_in_leaf=1771; max_depth=7; lambda_l1=1.24; lambda_l2=3.86; min_gain_to_split=0.0395 : y = 0.927 : 75.1 secs : infill_ei
#
# Saved the current state after iteration 154 in the file HT.RDATA.
#
# Sun Nov 30 05:58:56 PM 2025 AUC 0.930792276732649
#
# [mbo] 154: num_leaves=417; min_data_in_leaf=383; max_depth=17; lambda_l1=2.88; lambda_l2=3.27; min_gain_to_split=0.0874 : y = 0.931 : 102.4 secs : infill_ei
#
# Sun Nov 30 06:00:46 PM 2025 AUC 0.929642313458254
#
# [mbo] 155: num_leaves=556; min_data_in_leaf=413; max_depth=13; lambda_l1=3.15; lambda_l2=3.69; min_gain_to_split=0.049 : y = 0.93 : 108.2 secs : infill_ei
#
# Sun Nov 30 06:02:22 PM 2025 AUC 0.931473032747191
#
# [mbo] 156: num_leaves=633; min_data_in_leaf=439; max_depth=15; lambda_l1=1.4; lambda_l2=4.85; min_gain_to_split=0.145 : y = 0.931 : 95.3 secs : infill_ei
#
# Sun Nov 30 06:04:13 PM 2025 AUC 0.930583508465426
#
# [mbo] 157: num_leaves=110; min_data_in_leaf=430; max_depth=8; lambda_l1=4.25; lambda_l2=3.82; min_gain_to_split=0.0174 : y = 0.931 : 109.1 secs : infill_ei
#
# Sun Nov 30 06:05:37 PM 2025 AUC 0.927583362489834
#
# [mbo] 158: num_leaves=219; min_data_in_leaf=1890; max_depth=17; lambda_l1=0.708; lambda_l2=0.806; min_gain_to_split=0.171 : y = 0.928 : 82.8 secs : infill_ei
#
# Sun Nov 30 06:07:19 PM 2025 AUC 0.927719374668369
#
# [mbo] 159: num_leaves=291; min_data_in_leaf=1281; max_depth=12; lambda_l1=0.564; lambda_l2=3.22; min_gain_to_split=0.127 : y = 0.928 : 101.8 secs : infill_ei
#
# Saved the current state after iteration 160 in the file HT.RDATA.
#
# Sun Nov 30 06:08:50 PM 2025 AUC 0.93033025239875
#
# [mbo] 160: num_leaves=890; min_data_in_leaf=581; max_depth=10; lambda_l1=0.896; lambda_l2=3.72; min_gain_to_split=0.0623 : y = 0.93 : 89.6 secs : infill_ei
#
# Sun Nov 30 06:10:18 PM 2025 AUC 0.929709045157433
#
# [mbo] 161: num_leaves=568; min_data_in_leaf=506; max_depth=15; lambda_l1=4.11; lambda_l2=3.05; min_gain_to_split=0.162 : y = 0.93 : 87.0 secs : infill_ei
#
# Sun Nov 30 06:11:47 PM 2025 AUC 0.927866508796767
#
# [mbo] 162: num_leaves=821; min_data_in_leaf=1110; max_depth=15; lambda_l1=4.8; lambda_l2=3.28; min_gain_to_split=0.0534 : y = 0.928 : 87.5 secs : infill_ei
#
# Sun Nov 30 06:13:03 PM 2025 AUC 0.926549947981714
#
# [mbo] 163: num_leaves=192; min_data_in_leaf=1577; max_depth=16; lambda_l1=0.671; lambda_l2=0.86; min_gain_to_split=0.0805 : y = 0.927 : 75.2 secs : infill_ei
#
# Sun Nov 30 06:14:29 PM 2025 AUC 0.928972215978998
#
# [mbo] 164: num_leaves=226; min_data_in_leaf=741; max_depth=11; lambda_l1=1.87; lambda_l2=3.42; min_gain_to_split=0.0578 : y = 0.929 : 84.9 secs : infill_ei
#
# Sun Nov 30 06:15:39 PM 2025 AUC 0.926757326005204
#
# [mbo] 165: num_leaves=239; min_data_in_leaf=1109; max_depth=7; lambda_l1=4.16; lambda_l2=3.07; min_gain_to_split=0.114 : y = 0.927 : 68.8 secs : infill_ei
#
# Sun Nov 30 06:17:35 PM 2025 AUC 0.928362825809412
#
# [mbo] 166: num_leaves=474; min_data_in_leaf=617; max_depth=9; lambda_l1=4.96; lambda_l2=4.31; min_gain_to_split=0.0666 : y = 0.928 : 115.3 secs : infill_ei
#
# Saved the current state after iteration 167 in the file HT.RDATA.
#
# Sun Nov 30 06:20:33 PM 2025 AUC 0.933924959277444
#
# [mbo] 167: num_leaves=391; min_data_in_leaf=274; max_depth=10; lambda_l1=0.542; lambda_l2=3.09; min_gain_to_split=0.0518 : y = 0.934 : 176.0 secs : infill_ei
#
# Sun Nov 30 06:22:08 PM 2025 AUC 0.926531874813186
#
# [mbo] 168: num_leaves=831; min_data_in_leaf=1749; max_depth=17; lambda_l1=0.202; lambda_l2=3.09; min_gain_to_split=0.0569 : y = 0.927 : 94.1 secs : infill_ei
#
# Sun Nov 30 06:23:52 PM 2025 AUC 0.931970044881702
#
# [mbo] 169: num_leaves=383; min_data_in_leaf=239; max_depth=11; lambda_l1=0.542; lambda_l2=2.97; min_gain_to_split=0.0689 : y = 0.932 : 102.3 secs : infill_ei
#
# Sun Nov 30 06:25:35 PM 2025 AUC 0.927125972301711
#
# [mbo] 170: num_leaves=556; min_data_in_leaf=1446; max_depth=10; lambda_l1=3.52; lambda_l2=4.53; min_gain_to_split=0.0653 : y = 0.927 : 102.3 secs : infill_ei
#
# Sun Nov 30 06:27:12 PM 2025 AUC 0.925886106599255
#
# [mbo] 171: num_leaves=252; min_data_in_leaf=1745; max_depth=15; lambda_l1=3.82; lambda_l2=2.17; min_gain_to_split=0.0132 : y = 0.926 : 96.3 secs : infill_ei
#
# Sun Nov 30 06:28:21 PM 2025 AUC 0.928648984311099
#
# [mbo] 172: num_leaves=1011; min_data_in_leaf=1230; max_depth=7; lambda_l1=0.873; lambda_l2=1.59; min_gain_to_split=0.118 : y = 0.929 : 67.3 secs : infill_ei
#
# Saved the current state after iteration 173 in the file HT.RDATA.
#
# Sun Nov 30 06:29:44 PM 2025 AUC 0.926909789401245
#
# [mbo] 173: num_leaves=212; min_data_in_leaf=270; max_depth=9; lambda_l1=4.08; lambda_l2=4.52; min_gain_to_split=0.145 : y = 0.927 : 82.5 secs : infill_ei
#
# Sun Nov 30 06:31:20 PM 2025 AUC 0.927942045372921
#
# [mbo] 174: num_leaves=845; min_data_in_leaf=1069; max_depth=13; lambda_l1=2.14; lambda_l2=1.37; min_gain_to_split=0.0237 : y = 0.928 : 95.1 secs : infill_ei
#
# Sun Nov 30 06:32:55 PM 2025 AUC 0.933050495969452
#
# [mbo] 175: num_leaves=320; min_data_in_leaf=201; max_depth=11; lambda_l1=0.634; lambda_l2=3.37; min_gain_to_split=0.127 : y = 0.933 : 92.6 secs : infill_ei
#
# Sun Nov 30 06:35:21 PM 2025 AUC 0.931362740077715
#
# [mbo] 176: num_leaves=291; min_data_in_leaf=244; max_depth=11; lambda_l1=0.932; lambda_l2=3.34; min_gain_to_split=0.107 : y = 0.931 : 144.9 secs : infill_ei
#
# Sun Nov 30 06:37:11 PM 2025 AUC 0.928347996542927
#
# [mbo] 177: num_leaves=664; min_data_in_leaf=1585; max_depth=17; lambda_l1=2.47; lambda_l2=2.99; min_gain_to_split=0.158 : y = 0.928 : 109.2 secs : infill_ei
#
# Sun Nov 30 06:39:13 PM 2025 AUC 0.932162593638708
#
# [mbo] 178: num_leaves=589; min_data_in_leaf=317; max_depth=11; lambda_l1=2.26; lambda_l2=2.5; min_gain_to_split=0.172 : y = 0.932 : 120.6 secs : infill_ei
#
# Saved the current state after iteration 179 in the file HT.RDATA.
#
# Sun Nov 30 06:40:53 PM 2025 AUC 0.929042886702087
#
# [mbo] 179: num_leaves=995; min_data_in_leaf=353; max_depth=13; lambda_l1=2.41; lambda_l2=0.95; min_gain_to_split=0.0322 : y = 0.929 : 99.1 secs : infill_ei
#
# Sun Nov 30 06:42:27 PM 2025 AUC 0.929350593981635
#
# [mbo] 180: num_leaves=606; min_data_in_leaf=296; max_depth=6; lambda_l1=4.21; lambda_l2=1.91; min_gain_to_split=0.158 : y = 0.929 : 92.5 secs : infill_ei
#
# Sun Nov 30 06:44:12 PM 2025 AUC 0.931211435218118
#
# [mbo] 181: num_leaves=694; min_data_in_leaf=600; max_depth=11; lambda_l1=1.01; lambda_l2=3.17; min_gain_to_split=0.13 : y = 0.931 : 103.7 secs : infill_ei
#
# Sun Nov 30 06:45:45 PM 2025 AUC 0.925614545656763
#
# [mbo] 182: num_leaves=762; min_data_in_leaf=1807; max_depth=17; lambda_l1=0.721; lambda_l2=2.23; min_gain_to_split=0.0748 : y = 0.926 : 92.4 secs : infill_ei
#
# Sun Nov 30 06:47:12 PM 2025 AUC 0.92853730139789
#
# [mbo] 183: num_leaves=376; min_data_in_leaf=883; max_depth=12; lambda_l1=0.422; lambda_l2=1.53; min_gain_to_split=0.14 : y = 0.929 : 86.2 secs : infill_ei
#
# Sun Nov 30 06:48:45 PM 2025 AUC 0.931955910737084
#
# [mbo] 184: num_leaves=251; min_data_in_leaf=278; max_depth=12; lambda_l1=0.525; lambda_l2=3.27; min_gain_to_split=0.117 : y = 0.932 : 90.5 secs : infill_ei
#
# Sun Nov 30 06:50:45 PM 2025 AUC 0.933462239821678
#
# [mbo] 185: num_leaves=334; min_data_in_leaf=303; max_depth=12; lambda_l1=0.914; lambda_l2=3.08; min_gain_to_split=0.158 : y = 0.933 : 117.2 secs : infill_ei
#
# Saved the current state after iteration 186 in the file HT.RDATA.
#
# Sun Nov 30 06:52:10 PM 2025 AUC 0.926670899186476
#
# [mbo] 186: num_leaves=917; min_data_in_leaf=1561; max_depth=17; lambda_l1=4.6; lambda_l2=2.49; min_gain_to_split=0.13 : y = 0.927 : 83.1 secs : infill_ei
#
# Sun Nov 30 06:54:03 PM 2025 AUC 0.93031658166871
#
# [mbo] 187: num_leaves=829; min_data_in_leaf=346; max_depth=17; lambda_l1=0.114; lambda_l2=2.99; min_gain_to_split=0.0165 : y = 0.93 : 112.0 secs : infill_ei
#
# Sun Nov 30 06:55:44 PM 2025 AUC 0.930123106082548
#
# [mbo] 188: num_leaves=321; min_data_in_leaf=293; max_depth=10; lambda_l1=0.407; lambda_l2=3.08; min_gain_to_split=0.0713 : y = 0.93 : 98.9 secs : infill_ei
#
# Sun Nov 30 06:57:08 PM 2025 AUC 0.929244472043357
#
# [mbo] 189: num_leaves=145; min_data_in_leaf=573; max_depth=16; lambda_l1=4.46; lambda_l2=0.498; min_gain_to_split=0.106 : y = 0.929 : 82.3 secs : infill_ei
#
# Sun Nov 30 06:58:36 PM 2025 AUC 0.930353423127631
#
# [mbo] 190: num_leaves=615; min_data_in_leaf=781; max_depth=7; lambda_l1=1.03; lambda_l2=2.53; min_gain_to_split=0.167 : y = 0.93 : 86.8 secs : infill_ei
#
# Sun Nov 30 07:00:00 PM 2025 AUC 0.926883606477609
#
# [mbo] 191: num_leaves=277; min_data_in_leaf=1605; max_depth=11; lambda_l1=2.45; lambda_l2=1.33; min_gain_to_split=0.0569 : y = 0.927 : 83.0 secs : infill_ei
#
# Sun Nov 30 07:01:34 PM 2025 AUC 0.931303191304489
#
# [mbo] 192: num_leaves=78; min_data_in_leaf=405; max_depth=17; lambda_l1=1.3; lambda_l2=1.32; min_gain_to_split=0.161 : y = 0.931 : 93.4 secs : infill_ei
#
# Saved the current state after iteration 193 in the file HT.RDATA.
#
# Sun Nov 30 07:02:52 PM 2025 AUC 0.929318618375778
#
# [mbo] 193: num_leaves=524; min_data_in_leaf=685; max_depth=9; lambda_l1=3.02; lambda_l2=3.85; min_gain_to_split=0.0858 : y = 0.929 : 76.2 secs : infill_ei
#
# Sun Nov 30 07:04:45 PM 2025 AUC 0.927103960109273
#
# [mbo] 194: num_leaves=667; min_data_in_leaf=1153; max_depth=15; lambda_l1=1.16; lambda_l2=4.74; min_gain_to_split=0.0685 : y = 0.927 : 111.9 secs : infill_ei
#
# Sun Nov 30 07:06:16 PM 2025 AUC 0.930742227958265
#
# [mbo] 195: num_leaves=270; min_data_in_leaf=302; max_depth=11; lambda_l1=0.674; lambda_l2=2.82; min_gain_to_split=0.117 : y = 0.931 : 89.7 secs : infill_ei
#
# Sun Nov 30 07:07:44 PM 2025 AUC 0.930335118251815
#
# [mbo] 196: num_leaves=520; min_data_in_leaf=383; max_depth=10; lambda_l1=2.58; lambda_l2=1.2; min_gain_to_split=0.069 : y = 0.93 : 86.6 secs : infill_ei
#
# Sun Nov 30 07:09:16 PM 2025 AUC 0.928866325748009
#
# [mbo] 197: num_leaves=944; min_data_in_leaf=1026; max_depth=13; lambda_l1=1.27; lambda_l2=2.47; min_gain_to_split=0.0619 : y = 0.929 : 90.8 secs : infill_ei
#
# Sun Nov 30 07:11:07 PM 2025 AUC 0.931416727876009
#
# [mbo] 198: num_leaves=389; min_data_in_leaf=565; max_depth=18; lambda_l1=0.875; lambda_l2=4.81; min_gain_to_split=0.118 : y = 0.931 : 109.5 secs : infill_ei
#
# Sun Nov 30 07:12:19 PM 2025 AUC 0.927078704014792
#
# [mbo] 199: num_leaves=420; min_data_in_leaf=1957; max_depth=7; lambda_l1=1.19; lambda_l2=1.35; min_gain_to_split=0.165 : y = 0.927 : 71.4 secs : infill_ei
#
# Saved the current state after iteration 200 in the file HT.RDATA.
#
# Sun Nov 30 07:14:39 PM 2025 AUC 0.93317422766168
#
# [mbo] 200: num_leaves=452; min_data_in_leaf=272; max_depth=10; lambda_l1=0.212; lambda_l2=3.69; min_gain_to_split=0.127 : y = 0.933 : 137.5 secs : infill_ei
#
# Sun Nov 30 07:16:38 PM 2025 AUC 0.926894496720183
#
# [mbo] 201: num_leaves=517; min_data_in_leaf=1237; max_depth=8; lambda_l1=4.98; lambda_l2=3.12; min_gain_to_split=0.123 : y = 0.927 : 117.3 secs : infill_ei
#
# Sun Nov 30 07:18:21 PM 2025 AUC 0.925749631006143
#
# [mbo] 202: num_leaves=259; min_data_in_leaf=1987; max_depth=16; lambda_l1=3.68; lambda_l2=2.82; min_gain_to_split=0.186 : y = 0.926 : 101.3 secs : infill_ei
#
# Sun Nov 30 07:19:59 PM 2025 AUC 0.929788520757498
#
# [mbo] 203: num_leaves=112; min_data_in_leaf=824; max_depth=17; lambda_l1=3.73; lambda_l2=3.62; min_gain_to_split=0.072 : y = 0.93 : 97.6 secs : infill_ei
#
# Sun Nov 30 07:22:04 PM 2025 AUC 0.932249947286592
#
# [mbo] 204: num_leaves=770; min_data_in_leaf=236; max_depth=13; lambda_l1=0.956; lambda_l2=3.16; min_gain_to_split=0.11 : y = 0.932 : 123.8 secs : infill_ei
#
# Sun Nov 30 07:23:27 PM 2025 AUC 0.928232142898519
#
# [mbo] 205: num_leaves=805; min_data_in_leaf=1886; max_depth=13; lambda_l1=1.86; lambda_l2=0.559; min_gain_to_split=0.163 : y = 0.928 : 81.4 secs : infill_ei
#
# Saved the current state after iteration 206 in the file HT.RDATA.
#
# Sun Nov 30 07:24:38 PM 2025 AUC 0.92678165527053
#
# [mbo] 206: num_leaves=614; min_data_in_leaf=1690; max_depth=17; lambda_l1=0.697; lambda_l2=1.34; min_gain_to_split=0.129 : y = 0.927 : 70.5 secs : infill_ei
#
# Sun Nov 30 07:26:38 PM 2025 AUC 0.929758398809951
#
# [mbo] 207: num_leaves=475; min_data_in_leaf=785; max_depth=10; lambda_l1=4.69; lambda_l2=2.58; min_gain_to_split=0.16 : y = 0.93 : 118.0 secs : infill_ei
#
# Sun Nov 30 07:28:54 PM 2025 AUC 0.930503106036207
#
# [mbo] 208: num_leaves=440; min_data_in_leaf=713; max_depth=12; lambda_l1=4.87; lambda_l2=2.14; min_gain_to_split=0.148 : y = 0.931 : 135.9 secs : infill_ei
#
# Sun Nov 30 07:30:26 PM 2025 AUC 0.928823459899578
#
# [mbo] 209: num_leaves=89; min_data_in_leaf=763; max_depth=9; lambda_l1=2.39; lambda_l2=1.96; min_gain_to_split=0.0497 : y = 0.929 : 90.9 secs : infill_ei
#
# Sun Nov 30 07:31:41 PM 2025 AUC 0.926121521204692
#
# [mbo] 210: num_leaves=569; min_data_in_leaf=971; max_depth=6; lambda_l1=4.39; lambda_l2=3.28; min_gain_to_split=0.105 : y = 0.926 : 73.3 secs : infill_ei
#
# Sun Nov 30 07:33:34 PM 2025 AUC 0.930249849969531
#
# [mbo] 211: num_leaves=427; min_data_in_leaf=302; max_depth=15; lambda_l1=1.02; lambda_l2=3.95; min_gain_to_split=0.149 : y = 0.93 : 111.0 secs : infill_ei
#
# Saved the current state after iteration 212 in the file HT.RDATA.
#
# Sun Nov 30 07:34:36 PM 2025 AUC 0.926370374832881
#
# [mbo] 212: num_leaves=227; min_data_in_leaf=1728; max_depth=6; lambda_l1=0.375; lambda_l2=2.94; min_gain_to_split=0.0882 : y = 0.926 : 61.3 secs : infill_ei
#
# Sun Nov 30 07:36:20 PM 2025 AUC 0.926420655314554
#
# [mbo] 213: num_leaves=431; min_data_in_leaf=1429; max_depth=16; lambda_l1=4.58; lambda_l2=3.13; min_gain_to_split=0.117 : y = 0.926 : 102.8 secs : infill_ei
#
# Sun Nov 30 07:39:06 PM 2025 AUC 0.929399947634153
#
# [mbo] 214: num_leaves=232; min_data_in_leaf=859; max_depth=10; lambda_l1=0.508; lambda_l2=3.51; min_gain_to_split=0.0321 : y = 0.929 : 165.0 secs : infill_ei
#
# Sun Nov 30 07:40:11 PM 2025 AUC 0.928090801452341
#
# [mbo] 215: num_leaves=94; min_data_in_leaf=1180; max_depth=6; lambda_l1=0.235; lambda_l2=2; min_gain_to_split=0.0753 : y = 0.928 : 63.3 secs : infill_ei
#
# Sun Nov 30 07:41:36 PM 2025 AUC 0.92941616714437
#
# [mbo] 216: num_leaves=204; min_data_in_leaf=453; max_depth=14; lambda_l1=3.97; lambda_l2=1.81; min_gain_to_split=0.16 : y = 0.929 : 84.1 secs : infill_ei
#
# Sun Nov 30 07:43:43 PM 2025 AUC 0.932585922855375
#
# [mbo] 217: num_leaves=193; min_data_in_leaf=224; max_depth=10; lambda_l1=0.817; lambda_l2=3.35; min_gain_to_split=0.0702 : y = 0.933 : 125.5 secs : infill_ei
#
# Saved the current state after iteration 218 in the file HT.RDATA.
#
# Sun Nov 30 07:45:16 PM 2025 AUC 0.931095349866421
#
# [mbo] 218: num_leaves=233; min_data_in_leaf=244; max_depth=9; lambda_l1=1.12; lambda_l2=3.06; min_gain_to_split=0.0745 : y = 0.931 : 90.7 secs : infill_ei
#
# Sun Nov 30 07:46:45 PM 2025 AUC 0.931690374184101
#
# [mbo] 219: num_leaves=217; min_data_in_leaf=328; max_depth=10; lambda_l1=1.04; lambda_l2=0.141; min_gain_to_split=0.0735 : y = 0.932 : 86.5 secs : infill_ei
#
# Sun Nov 30 07:48:09 PM 2025 AUC 0.927607460047871
#
# [mbo] 220: num_leaves=964; min_data_in_leaf=1886; max_depth=10; lambda_l1=2.38; lambda_l2=4.05; min_gain_to_split=0.0503 : y = 0.928 : 82.8 secs : infill_ei
#
# Sun Nov 30 07:50:07 PM 2025 AUC 0.930428496289208
#
# [mbo] 221: num_leaves=449; min_data_in_leaf=754; max_depth=13; lambda_l1=4.71; lambda_l2=0.713; min_gain_to_split=0.143 : y = 0.93 : 117.1 secs : infill_ei
#
# Sun Nov 30 07:51:28 PM 2025 AUC 0.926052240725337
#
# [mbo] 222: num_leaves=715; min_data_in_leaf=1613; max_depth=18; lambda_l1=4.29; lambda_l2=0.785; min_gain_to_split=0.112 : y = 0.926 : 78.4 secs : infill_ei
#
# Sun Nov 30 07:52:55 PM 2025 AUC 0.927282838136239
#
# [mbo] 223: num_leaves=175; min_data_in_leaf=1298; max_depth=11; lambda_l1=2.71; lambda_l2=2.36; min_gain_to_split=0.125 : y = 0.927 : 86.1 secs : infill_ei
#
# Sun Nov 30 07:54:49 PM 2025 AUC 0.930197715829547
#
# [mbo] 224: num_leaves=290; min_data_in_leaf=370; max_depth=15; lambda_l1=2.3; lambda_l2=1.09; min_gain_to_split=0.0643 : y = 0.93 : 113.5 secs : infill_ei
#
# Saved the current state after iteration 225 in the file HT.RDATA.
#
# Sun Nov 30 07:56:27 PM 2025 AUC 0.931575910783425
#
# [mbo] 225: num_leaves=297; min_data_in_leaf=266; max_depth=9; lambda_l1=0.608; lambda_l2=4.46; min_gain_to_split=0.11 : y = 0.932 : 94.7 secs : infill_ei
#
# Sun Nov 30 07:58:10 PM 2025 AUC 0.928015959998054
#
# [mbo] 226: num_leaves=168; min_data_in_leaf=696; max_depth=14; lambda_l1=2.81; lambda_l2=0.151; min_gain_to_split=0.0866 : y = 0.928 : 102.7 secs : infill_ei
#
# Sun Nov 30 07:59:39 PM 2025 AUC 0.927173240588629
#
# [mbo] 227: num_leaves=823; min_data_in_leaf=1931; max_depth=11; lambda_l1=1.93; lambda_l2=3.98; min_gain_to_split=0.0269 : y = 0.927 : 87.9 secs : infill_ei
#
# Sun Nov 30 08:01:24 PM 2025 AUC 0.929566545174812
#
# [mbo] 228: num_leaves=254; min_data_in_leaf=276; max_depth=10; lambda_l1=0.848; lambda_l2=1.86; min_gain_to_split=0.0701 : y = 0.93 : 100.0 secs : infill_ei
#
# Sun Nov 30 08:03:29 PM 2025 AUC 0.931567337613739
#
# [mbo] 229: num_leaves=943; min_data_in_leaf=362; max_depth=10; lambda_l1=0.677; lambda_l2=3.06; min_gain_to_split=0.0691 : y = 0.932 : 124.1 secs : infill_ei
#
# Sun Nov 30 08:06:19 PM 2025 AUC 0.931141691324184
#
# [mbo] 230: num_leaves=272; min_data_in_leaf=278; max_depth=10; lambda_l1=0.694; lambda_l2=3; min_gain_to_split=0.0573 : y = 0.931 : 164.7 secs : infill_ei
#
# Saved the current state after iteration 231 in the file HT.RDATA.
#
# Sun Nov 30 08:08:10 PM 2025 AUC 0.930757288932038
#
# [mbo] 231: num_leaves=631; min_data_in_leaf=274; max_depth=12; lambda_l1=0.4; lambda_l2=2.25; min_gain_to_split=0.0985 : y = 0.931 : 107.7 secs : infill_ei
#
# Sun Nov 30 08:09:56 PM 2025 AUC 0.928111423401046
#
# [mbo] 232: num_leaves=529; min_data_in_leaf=756; max_depth=7; lambda_l1=4.47; lambda_l2=2.72; min_gain_to_split=0.0786 : y = 0.928 : 104.2 secs : infill_ei
#
# Sun Nov 30 08:11:22 PM 2025 AUC 0.929951179274246
#
# [mbo] 233: num_leaves=223; min_data_in_leaf=235; max_depth=10; lambda_l1=2.36; lambda_l2=0.915; min_gain_to_split=0.0756 : y = 0.93 : 84.8 secs : infill_ei
#
# Sun Nov 30 08:13:12 PM 2025 AUC 0.93011291096184
#
# [mbo] 234: num_leaves=209; min_data_in_leaf=309; max_depth=12; lambda_l1=0.878; lambda_l2=2.62; min_gain_to_split=0.138 : y = 0.93 : 107.4 secs : infill_ei
#
# Sun Nov 30 08:15:17 PM 2025 AUC 0.931719105887914
#
# [mbo] 235: num_leaves=446; min_data_in_leaf=294; max_depth=11; lambda_l1=0.425; lambda_l2=3.09; min_gain_to_split=0.133 : y = 0.932 : 122.4 secs : infill_ei
#
# Sun Nov 30 08:16:49 PM 2025 AUC 0.928858215992901
#
# [mbo] 236: num_leaves=824; min_data_in_leaf=783; max_depth=8; lambda_l1=4.21; lambda_l2=2.8; min_gain_to_split=0.158 : y = 0.929 : 89.9 secs : infill_ei
#
# Saved the current state after iteration 237 in the file HT.RDATA.
#
# Sun Nov 30 08:18:35 PM 2025 AUC 0.929497728110033
#
# [mbo] 237: num_leaves=519; min_data_in_leaf=391; max_depth=16; lambda_l1=3.34; lambda_l2=3.06; min_gain_to_split=0.105 : y = 0.929 : 105.4 secs : infill_ei
#
# Sun Nov 30 08:20:42 PM 2025 AUC 0.928957386712514
#
# [mbo] 238: num_leaves=742; min_data_in_leaf=1004; max_depth=15; lambda_l1=0.734; lambda_l2=1.89; min_gain_to_split=0.186 : y = 0.929 : 125.7 secs : infill_ei
#
# Sun Nov 30 08:23:41 PM 2025 AUC 0.930773971856833
#
# [mbo] 239: num_leaves=190; min_data_in_leaf=289; max_depth=15; lambda_l1=0.537; lambda_l2=3.17; min_gain_to_split=0.0732 : y = 0.931 : 175.0 secs : infill_ei
#
# Sun Nov 30 08:25:21 PM 2025 AUC 0.92901299646183
#
# [mbo] 240: num_leaves=977; min_data_in_leaf=677; max_depth=7; lambda_l1=3.32; lambda_l2=3.3; min_gain_to_split=0.108 : y = 0.929 : 98.4 secs : infill_ei
#
# Sun Nov 30 08:27:10 PM 2025 AUC 0.931632679069185
#
# [mbo] 241: num_leaves=207; min_data_in_leaf=357; max_depth=11; lambda_l1=0.444; lambda_l2=3.33; min_gain_to_split=0.0733 : y = 0.932 : 106.7 secs : infill_ei
#
# Saved the current state after iteration 242 in the file HT.RDATA.
#
# Sun Nov 30 08:28:37 PM 2025 AUC 0.928249984359758
#
# [mbo] 242: num_leaves=102; min_data_in_leaf=657; max_depth=7; lambda_l1=1.26; lambda_l2=2.03; min_gain_to_split=0.0602 : y = 0.928 : 85.4 secs : infill_ei
#
# Sun Nov 30 08:30:59 PM 2025 AUC 0.9290716184059
#
# [mbo] 243: num_leaves=271; min_data_in_leaf=230; max_depth=10; lambda_l1=3.56; lambda_l2=4.63; min_gain_to_split=0.184 : y = 0.929 : 141.3 secs : infill_ei
#
# Sun Nov 30 08:32:23 PM 2025 AUC 0.928062069748528
#
# [mbo] 244: num_leaves=97; min_data_in_leaf=1545; max_depth=15; lambda_l1=2.09; lambda_l2=0.951; min_gain_to_split=0.092 : y = 0.928 : 82.7 secs : infill_ei
#
# Sun Nov 30 08:34:53 PM 2025 AUC 0.932125983887075
#
# [mbo] 245: num_leaves=391; min_data_in_leaf=229; max_depth=12; lambda_l1=0.128; lambda_l2=2.76; min_gain_to_split=0.151 : y = 0.932 : 147.4 secs : infill_ei
#
# Sun Nov 30 08:36:25 PM 2025 AUC 0.929951179274246
#
# [mbo] 246: num_leaves=393; min_data_in_leaf=306; max_depth=11; lambda_l1=0.169; lambda_l2=2.48; min_gain_to_split=0.127 : y = 0.93 : 89.2 secs : infill_ei
#
# Sun Nov 30 08:37:27 PM 2025 AUC 0.927401240560824
#
# [mbo] 247: num_leaves=601; min_data_in_leaf=1511; max_depth=7; lambda_l1=0.659; lambda_l2=2.57; min_gain_to_split=0.128 : y = 0.927 : 61.1 secs : infill_ei
#
# Saved the current state after iteration 248 in the file HT.RDATA.
#
# Sun Nov 30 08:39:02 PM 2025 AUC 0.926466996772317
#
# [mbo] 248: num_leaves=773; min_data_in_leaf=1680; max_depth=18; lambda_l1=0.537; lambda_l2=3.79; min_gain_to_split=0.158 : y = 0.926 : 93.2 secs : infill_ei
#
# Sun Nov 30 08:41:29 PM 2025 AUC 0.929915032937191
#
# [mbo] 249: num_leaves=345; min_data_in_leaf=827; max_depth=16; lambda_l1=0.817; lambda_l2=4.84; min_gain_to_split=0.158 : y = 0.93 : 146.1 secs : infill_ei
#
# Sun Nov 30 08:42:49 PM 2025 AUC 0.925890509037743
#
# [mbo] 250: num_leaves=494; min_data_in_leaf=1573; max_depth=15; lambda_l1=1.68; lambda_l2=1.04; min_gain_to_split=0.179 : y = 0.926 : 78.4 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf max_depth lambda_l1 lambda_l2 min_gain_to_split
#         <int>            <int>     <int>     <num>     <num>             <num>
# 1:        289              279        10 0.5291058  3.061922        0.07016705
#    num_iterations
#             <int>
# 1:            463

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 240562

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Warning message in dir.create("kaggle"):
# “'kaggle' already exists”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 08:44:36 PM 2025"

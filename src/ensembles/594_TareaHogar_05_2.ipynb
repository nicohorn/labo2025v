# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 02:19:34 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454482    77.7 1454482  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 59412
PARAM$semilla_primigenia <- 153929

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# PRIMERO: Define xval_folds
PARAM$hyperparametertuning$xval_folds <- 5

# SEGUNDO: Define param_fijos (asegúrate de que xval_folds ya existe)
PARAM$lgbm$param_fijos <- list(
  boosting = "gbdt",
  objective = "binary",
  metric = "auc",
  first_metric_only = FALSE,
  boost_from_average = TRUE,
  feature_pre_filter = FALSE,
  force_row_wise = TRUE,
  verbosity = -100,
  seed = PARAM$semilla_primigenia,

  max_depth = -1L,
  min_gain_to_split = 0.0,
  min_sum_hessian_in_leaf = 0.001,
  lambda_l1 = 0.0,
  lambda_l2 = 0.0,
  max_bin = 31L,

  bagging_fraction = 1.0,
  pos_bagging_fraction = 1.0,
  neg_bagging_fraction = 1.0,
  is_unbalance = FALSE,
  scale_pos_weight = 1.0,

  drop_rate = 0.1,
  max_drop = 50,
  skip_drop = 0.5,
  extra_trees = FALSE,

  num_iterations = 1200,
  learning_rate = 0.02,
  feature_fraction = 0.5,
  num_leaves = 750,
  min_data_in_leaf = 5000
)

# VERIFICAR que xval_folds tiene un valor válido
print(paste("xval_folds =", PARAM$hyperparametertuning$xval_folds))
# Out:
# [1] "xval_folds = 5"

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83349
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 04 02:37:50 PM 2025 AUC 0.92466682966951
#
# Tue Nov 04 02:38:42 PM 2025 AUC 0.926115691454059
#
# Tue Nov 04 02:41:35 PM 2025 AUC 0.925244458554191
#
# Tue Nov 04 02:44:24 PM 2025 AUC 0.925275180268281
#
# Tue Nov 04 02:46:01 PM 2025 AUC 0.924261543392765
#
# Tue Nov 04 02:48:33 PM 2025 AUC 0.923397795594777
#
# Tue Nov 04 02:51:40 PM 2025 AUC 0.926130592573271
#
# Tue Nov 04 02:52:35 PM 2025 AUC 0.92575528584051
#
# Tue Nov 04 02:54:10 PM 2025 AUC 0.925329054812681
#
# Tue Nov 04 03:00:37 PM 2025 AUC 0.927031886689204
#
# Tue Nov 04 03:03:48 PM 2025 AUC 0.922866704751722
#
# Tue Nov 04 03:09:26 PM 2025 AUC 0.924906042928204
#
# Tue Nov 04 03:13:02 PM 2025 AUC 0.926062868436185
#
# Tue Nov 04 03:13:22 PM 2025 AUC 0.924009467291986
#
# Tue Nov 04 03:14:42 PM 2025 AUC 0.92829492455583
#
# Tue Nov 04 03:17:32 PM 2025 AUC 0.922476801982636
#
# Tue Nov 04 03:17:47 PM 2025 AUC 0.923328099593676
#
# Tue Nov 04 03:26:53 PM 2025 AUC 0.926430607964189
#
# Tue Nov 04 03:28:12 PM 2025 AUC 0.924425322286259
#
# Tue Nov 04 03:33:19 PM 2025 AUC 0.925386597262316
#
# [mbo] 0: num_iterations=927; learning_rate=0.233; feature_fraction=0.458; num_leaves=1623; min_data_in_leaf=866 : y = 0.925 : 233.1 secs : initdesign
#
# [mbo] 0: num_iterations=243; learning_rate=0.0586; feature_fraction=0.483; num_leaves=814; min_data_in_leaf=4762 : y = 0.926 : 52.0 secs : initdesign
#
# [mbo] 0: num_iterations=1432; learning_rate=0.208; feature_fraction=0.773; num_leaves=1771; min_data_in_leaf=3685 : y = 0.925 : 173.1 secs : initdesign
#
# [mbo] 0: num_iterations=855; learning_rate=0.104; feature_fraction=0.536; num_leaves=941; min_data_in_leaf=6396 : y = 0.925 : 168.8 secs : initdesign
#
# [mbo] 0: num_iterations=638; learning_rate=0.213; feature_fraction=0.222; num_leaves=837; min_data_in_leaf=4804 : y = 0.924 : 96.5 secs : initdesign
#
# [mbo] 0: num_iterations=1518; learning_rate=0.191; feature_fraction=0.726; num_leaves=591; min_data_in_leaf=6795 : y = 0.923 : 152.5 secs : initdesign
#
# [mbo] 0: num_iterations=1094; learning_rate=0.15; feature_fraction=0.633; num_leaves=1208; min_data_in_leaf=1491 : y = 0.926 : 186.5 secs : initdesign
#
# [mbo] 0: num_iterations=401; learning_rate=0.027; feature_fraction=0.139; num_leaves=110; min_data_in_leaf=2779 : y = 0.926 : 55.3 secs : initdesign
#
# [mbo] 0: num_iterations=555; learning_rate=0.158; feature_fraction=0.594; num_leaves=361; min_data_in_leaf=3359 : y = 0.925 : 94.8 secs : initdesign
#
# [mbo] 0: num_iterations=1849; learning_rate=0.0771; feature_fraction=0.405; num_leaves=1486; min_data_in_leaf=2109 : y = 0.927 : 387.8 secs : initdesign
#
# [mbo] 0: num_iterations=1203; learning_rate=0.282; feature_fraction=0.271; num_leaves=1677; min_data_in_leaf=7133 : y = 0.923 : 190.6 secs : initdesign
#
# [mbo] 0: num_iterations=1552; learning_rate=0.17; feature_fraction=0.34; num_leaves=681; min_data_in_leaf=587 : y = 0.925 : 338.5 secs : initdesign
#
# [mbo] 0: num_iterations=2024; learning_rate=0.137; feature_fraction=0.871; num_leaves=1430; min_data_in_leaf=5943 : y = 0.926 : 215.8 secs : initdesign
#
# [mbo] 0: num_iterations=201; learning_rate=0.249; feature_fraction=0.911; num_leaves=463; min_data_in_leaf=7245 : y = 0.924 : 20.1 secs : initdesign
#
# [mbo] 0: num_iterations=511; learning_rate=0.02; feature_fraction=0.677; num_leaves=1070; min_data_in_leaf=1664 : y = 0.928 : 80.0 secs : initdesign
#
# [mbo] 0: num_iterations=1295; learning_rate=0.286; feature_fraction=0.786; num_leaves=1258; min_data_in_leaf=3127 : y = 0.922 : 169.7 secs : initdesign
#
# [mbo] 0: num_iterations=97; learning_rate=0.263; feature_fraction=0.154; num_leaves=291; min_data_in_leaf=4115 : y = 0.923 : 14.7 secs : initdesign
#
# [mbo] 0: num_iterations=1688; learning_rate=0.0438; feature_fraction=0.86; num_leaves=1937; min_data_in_leaf=56 : y = 0.926 : 546.3 secs : initdesign
#
# [mbo] 0: num_iterations=774; learning_rate=0.0878; feature_fraction=0.97; num_leaves=1981; min_data_in_leaf=7918 : y = 0.924 : 78.6 secs : initdesign
#
# [mbo] 0: num_iterations=1796; learning_rate=0.114; feature_fraction=0.324; num_leaves=106; min_data_in_leaf=5282 : y = 0.925 : 306.9 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:44:29 PM 2025 AUC 0.923749101662113
#
# [mbo] 1: num_iterations=1019; learning_rate=0.0105; feature_fraction=0.669; num_leaves=1188; min_data_in_leaf=2 : y = 0.924 : 669.9 secs : infill_ei
#
# Saved the current state after iteration 2 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:46:06 PM 2025 AUC 0.92867898542091
#
# [mbo] 2: num_iterations=530; learning_rate=0.0178; feature_fraction=0.857; num_leaves=1703; min_data_in_leaf=1074 : y = 0.929 : 95.7 secs : infill_ei
#
# Tue Nov 04 03:47:15 PM 2025 AUC 0.925843432302645
#
# [mbo] 3: num_iterations=484; learning_rate=0.012; feature_fraction=0.92; num_leaves=1635; min_data_in_leaf=2389 : y = 0.926 : 68.6 secs : infill_ei
#
# Tue Nov 04 03:48:54 PM 2025 AUC 0.926517366206932
#
# [mbo] 4: num_iterations=830; learning_rate=0.0187; feature_fraction=0.952; num_leaves=1794; min_data_in_leaf=3977 : y = 0.927 : 99.3 secs : infill_ei
#
# Tue Nov 04 03:50:18 PM 2025 AUC 0.929223576076679
#
# [mbo] 5: num_iterations=514; learning_rate=0.0308; feature_fraction=0.723; num_leaves=1526; min_data_in_leaf=1299 : y = 0.929 : 83.5 secs : infill_ei
#
# Tue Nov 04 03:52:19 PM 2025 AUC 0.92858654751954
#
# [mbo] 6: num_iterations=728; learning_rate=0.0478; feature_fraction=0.878; num_leaves=1997; min_data_in_leaf=1265 : y = 0.929 : 120.7 secs : infill_ei
#
# Tue Nov 04 03:54:58 PM 2025 AUC 0.927781312457502
#
# [mbo] 7: num_iterations=978; learning_rate=0.0275; feature_fraction=0.872; num_leaves=1578; min_data_in_leaf=1386 : y = 0.928 : 157.9 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:56:19 PM 2025 AUC 0.928199266727366
#
# [mbo] 8: num_iterations=443; learning_rate=0.025; feature_fraction=0.867; num_leaves=1981; min_data_in_leaf=976 : y = 0.928 : 81.0 secs : infill_ei
#
# Tue Nov 04 03:58:25 PM 2025 AUC 0.92834428357572
#
# [mbo] 9: num_iterations=546; learning_rate=0.0431; feature_fraction=0.434; num_leaves=1418; min_data_in_leaf=1268 : y = 0.928 : 125.2 secs : infill_ei
#
# Tue Nov 04 03:58:42 PM 2025 AUC 0.925458672686172
#
# [mbo] 10: num_iterations=99; learning_rate=0.0432; feature_fraction=0.707; num_leaves=1671; min_data_in_leaf=1197 : y = 0.925 : 17.2 secs : infill_ei
#
# Tue Nov 04 04:00:22 PM 2025 AUC 0.929572463203223
#
# [mbo] 11: num_iterations=550; learning_rate=0.0265; feature_fraction=0.848; num_leaves=1740; min_data_in_leaf=994 : y = 0.93 : 98.8 secs : infill_ei
#
# Tue Nov 04 04:02:16 PM 2025 AUC 0.929332119238672
#
# [mbo] 12: num_iterations=644; learning_rate=0.0313; feature_fraction=0.769; num_leaves=1732; min_data_in_leaf=1019 : y = 0.929 : 113.2 secs : infill_ei
#
# Tue Nov 04 04:04:47 PM 2025 AUC 0.930054129087631
#
# [mbo] 13: num_iterations=578; learning_rate=0.0254; feature_fraction=0.453; num_leaves=1576; min_data_in_leaf=640 : y = 0.93 : 151.4 secs : infill_ei
#
# Tue Nov 04 04:08:22 PM 2025 AUC 0.928024464926343
#
# [mbo] 14: num_iterations=545; learning_rate=0.0262; feature_fraction=0.405; num_leaves=1437; min_data_in_leaf=114 : y = 0.928 : 214.0 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:10:23 PM 2025 AUC 0.929929804151563
#
# [mbo] 15: num_iterations=550; learning_rate=0.0275; feature_fraction=0.602; num_leaves=1542; min_data_in_leaf=747 : y = 0.93 : 120.7 secs : infill_ei
#
# Tue Nov 04 04:13:38 PM 2025 AUC 0.929065336991954
#
# [mbo] 16: num_iterations=699; learning_rate=0.0253; feature_fraction=0.514; num_leaves=1758; min_data_in_leaf=558 : y = 0.929 : 194.3 secs : infill_ei
#
# Tue Nov 04 04:15:46 PM 2025 AUC 0.928729071084725
#
# [mbo] 17: num_iterations=593; learning_rate=0.0244; feature_fraction=0.579; num_leaves=1796; min_data_in_leaf=1454 : y = 0.929 : 127.9 secs : infill_ei
#
# Tue Nov 04 04:20:34 PM 2025 AUC 0.929591534188629
#
# [mbo] 18: num_iterations=1186; learning_rate=0.0292; feature_fraction=0.407; num_leaves=1547; min_data_in_leaf=717 : y = 0.93 : 287.0 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:26:18 PM 2025 AUC 0.926476246422882
#
# [mbo] 19: num_iterations=737; learning_rate=0.0326; feature_fraction=0.324; num_leaves=1589; min_data_in_leaf=42 : y = 0.926 : 343.7 secs : infill_ei
#
# Tue Nov 04 04:30:19 PM 2025 AUC 0.928391246551918
#
# [mbo] 20: num_iterations=1037; learning_rate=0.0281; feature_fraction=0.489; num_leaves=1560; min_data_in_leaf=1664 : y = 0.928 : 240.5 secs : infill_ei
#
# Tue Nov 04 04:33:35 PM 2025 AUC 0.927829016170002
#
# [mbo] 21: num_iterations=1208; learning_rate=0.0367; feature_fraction=0.151; num_leaves=1629; min_data_in_leaf=992 : y = 0.928 : 195.4 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:36:04 PM 2025 AUC 0.929112094828231
#
# [mbo] 22: num_iterations=615; learning_rate=0.0263; feature_fraction=0.453; num_leaves=764; min_data_in_leaf=1022 : y = 0.929 : 148.5 secs : infill_ei
#
# Tue Nov 04 04:38:06 PM 2025 AUC 0.928948926669523
#
# [mbo] 23: num_iterations=648; learning_rate=0.059; feature_fraction=0.998; num_leaves=1332; min_data_in_leaf=838 : y = 0.929 : 122.0 secs : infill_ei
#
# Tue Nov 04 04:43:42 PM 2025 AUC 0.930057054154907
#
# [mbo] 24: num_iterations=1320; learning_rate=0.0258; feature_fraction=0.504; num_leaves=1588; min_data_in_leaf=944 : y = 0.93 : 335.5 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:48:07 PM 2025 AUC 0.930548506175101
#
# [mbo] 25: num_iterations=1274; learning_rate=0.0253; feature_fraction=0.618; num_leaves=1415; min_data_in_leaf=739 : y = 0.931 : 264.9 secs : infill_ei
#
# Tue Nov 04 04:53:26 PM 2025 AUC 0.930121340727916
#
# [mbo] 26: num_iterations=1380; learning_rate=0.0265; feature_fraction=0.405; num_leaves=1404; min_data_in_leaf=981 : y = 0.93 : 318.0 secs : infill_ei
#
# Tue Nov 04 04:58:21 PM 2025 AUC 0.929544009123306
#
# [mbo] 27: num_iterations=1294; learning_rate=0.0273; feature_fraction=0.544; num_leaves=1446; min_data_in_leaf=1784 : y = 0.93 : 294.1 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:02:48 PM 2025 AUC 0.929261492404775
#
# [mbo] 28: num_iterations=1387; learning_rate=0.0264; feature_fraction=0.863; num_leaves=1229; min_data_in_leaf=738 : y = 0.929 : 266.9 secs : infill_ei
#
# Tue Nov 04 05:04:42 PM 2025 AUC 0.929009731728515
#
# [mbo] 29: num_iterations=603; learning_rate=0.0242; feature_fraction=0.203; num_leaves=1399; min_data_in_leaf=905 : y = 0.929 : 113.2 secs : infill_ei
#
# Tue Nov 04 05:10:52 PM 2025 AUC 0.929851123677362
#
# [mbo] 30: num_iterations=1583; learning_rate=0.0253; feature_fraction=0.587; num_leaves=1267; min_data_in_leaf=813 : y = 0.93 : 369.7 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:14:19 PM 2025 AUC 0.929783150241608
#
# [mbo] 31: num_iterations=1158; learning_rate=0.0251; feature_fraction=0.709; num_leaves=1444; min_data_in_leaf=918 : y = 0.93 : 207.1 secs : infill_ei
#
# Tue Nov 04 05:18:41 PM 2025 AUC 0.930986290234763
#
# [mbo] 32: num_iterations=1122; learning_rate=0.0252; feature_fraction=0.369; num_leaves=1464; min_data_in_leaf=727 : y = 0.931 : 261.3 secs : infill_ei
#
# Tue Nov 04 05:23:41 PM 2025 AUC 0.929068969642807
#
# [mbo] 33: num_iterations=1242; learning_rate=0.0238; feature_fraction=0.402; num_leaves=1165; min_data_in_leaf=727 : y = 0.929 : 299.2 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:27:24 PM 2025 AUC 0.930699155605027
#
# [mbo] 34: num_iterations=1135; learning_rate=0.0248; feature_fraction=0.214; num_leaves=1490; min_data_in_leaf=658 : y = 0.931 : 222.6 secs : infill_ei
#
# Tue Nov 04 05:31:26 PM 2025 AUC 0.929704673368266
#
# [mbo] 35: num_iterations=1200; learning_rate=0.0258; feature_fraction=0.242; num_leaves=1378; min_data_in_leaf=676 : y = 0.93 : 241.2 secs : infill_ei
#
# Tue Nov 04 05:36:14 PM 2025 AUC 0.9297034558632
#
# [mbo] 36: num_iterations=1125; learning_rate=0.0227; feature_fraction=0.332; num_leaves=1532; min_data_in_leaf=353 : y = 0.93 : 287.2 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:39:43 PM 2025 AUC 0.929159827429829
#
# [mbo] 37: num_iterations=969; learning_rate=0.0293; feature_fraction=0.59; num_leaves=1111; min_data_in_leaf=962 : y = 0.929 : 208.7 secs : infill_ei
#
# Tue Nov 04 05:45:34 PM 2025 AUC 0.930253673653258
#
# [mbo] 38: num_iterations=1393; learning_rate=0.0224; feature_fraction=0.567; num_leaves=1469; min_data_in_leaf=739 : y = 0.93 : 350.5 secs : infill_ei
#
# Tue Nov 04 05:49:43 PM 2025 AUC 0.928593947379263
#
# [mbo] 39: num_iterations=1465; learning_rate=0.0251; feature_fraction=0.63; num_leaves=1429; min_data_in_leaf=1358 : y = 0.929 : 248.9 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:59:52 PM 2025 AUC 0.926450244122548
#
# [mbo] 40: num_iterations=1182; learning_rate=0.0251; feature_fraction=0.547; num_leaves=1478; min_data_in_leaf=24 : y = 0.926 : 608.0 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:04:37 PM 2025 AUC 0.929954747065067
#
# [mbo] 41: num_iterations=1198; learning_rate=0.0248; feature_fraction=0.397; num_leaves=1546; min_data_in_leaf=742 : y = 0.93 : 285.0 secs : infill_ei
#
# Tue Nov 04 06:08:28 PM 2025 AUC 0.929825796061751
#
# [mbo] 42: num_iterations=1113; learning_rate=0.0243; feature_fraction=0.298; num_leaves=1900; min_data_in_leaf=901 : y = 0.93 : 230.2 secs : infill_ei
#
# Tue Nov 04 06:12:01 PM 2025 AUC 0.930057038187756
#
# [mbo] 43: num_iterations=937; learning_rate=0.0242; feature_fraction=0.35; num_leaves=1465; min_data_in_leaf=710 : y = 0.93 : 212.7 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:21:13 PM 2025 AUC 0.930158031858189
#
# [mbo] 44: num_iterations=2047; learning_rate=0.0197; feature_fraction=0.54; num_leaves=1392; min_data_in_leaf=645 : y = 0.93 : 551.0 secs : infill_ei
#
# Tue Nov 04 06:28:21 PM 2025 AUC 0.930606466803798
#
# [mbo] 45: num_iterations=1856; learning_rate=0.0244; feature_fraction=0.363; num_leaves=1420; min_data_in_leaf=763 : y = 0.931 : 427.0 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:32:16 PM 2025 AUC 0.930010552849471
#
# [mbo] 46: num_iterations=1234; learning_rate=0.021; feature_fraction=0.207; num_leaves=1748; min_data_in_leaf=624 : y = 0.93 : 234.9 secs : infill_ei
#
# Tue Nov 04 06:38:04 PM 2025 AUC 0.926296446149274
#
# [mbo] 47: num_iterations=2005; learning_rate=0.0101; feature_fraction=0.323; num_leaves=1328; min_data_in_leaf=4869 : y = 0.926 : 347.2 secs : infill_ei
#
# Tue Nov 04 06:44:31 PM 2025 AUC 0.928842861436996
#
# [mbo] 48: num_iterations=1983; learning_rate=0.0253; feature_fraction=0.269; num_leaves=1801; min_data_in_leaf=1005 : y = 0.929 : 386.0 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:51:20 PM 2025 AUC 0.930460632981012
#
# [mbo] 49: num_iterations=1650; learning_rate=0.0209; feature_fraction=0.459; num_leaves=1655; min_data_in_leaf=868 : y = 0.93 : 409.3 secs : infill_ei
#
# Tue Nov 04 06:58:43 PM 2025 AUC 0.930113677277033
#
# [mbo] 50: num_iterations=1741; learning_rate=0.0153; feature_fraction=0.45; num_leaves=1421; min_data_in_leaf=677 : y = 0.93 : 441.5 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1122    0.02520605        0.3692065       1464              727
# [1] 0.9309863

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 153929
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1122
#
# $learning_rate
# [1] 0.02520605
#
# $feature_fraction
# [1] 0.3692065
#
# $num_leaves
# [1] 1464
#
# $min_data_in_leaf
# [1] 727

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 07:05:46 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
